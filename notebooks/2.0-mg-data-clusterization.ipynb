# %%
from typing import List

import pandas as pd
from collections import defaultdict
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('../data/raw/train.csv')
data.head()
# Out:
#    pair_id                             name_1  \
# 0        1                Iko Industries Ltd.
# 1        2            Apcotex Industries Ltd.
# 2        3  Rishichem Distributors Pvt., Ltd.
# 3        4            Powermax Rubber Factory
# 4        5                          Tress A/S
#
#                                  name_2  is_duplicate
# 0  Enormous Industrial Trade Pvt., Ltd.             0
# 1   Technocraft Industries (India) Ltd.             0
# 2                                   Dsa             0
# 3                               Co. One             0
# 4      Longyou Industries Park Zhejiang             0

# %% [markdown]
# # Разделим на train/test

# %%
X = data.drop(['is_duplicate'], axis = 1)
y = data.is_duplicate

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state = 666,
    stratify = y,
    test_size = 0.2
)

# %%
X_train['is_duplicate'] = y_train
X_test['is_duplicate'] = y_test

# %% [markdown]
# ## Используем транзитивность

# %%
class_1 = X_train[X_train['is_duplicate'] == 1].reset_index(drop=True)
class_1 = class_1[class_1['name_1'] != class_1['name_2']].reset_index(drop=True)
name_1_duplicates = class_1['name_1']
name_2_duplicates = class_1['name_2']
unique_companies_class_1 = pd.concat([name_1_duplicates, name_2_duplicates]).unique()
len(unique_companies_class_1)
# Out:
# 1204

# %%
names_clusters = {}
n_clusters = 0
for name in sorted(unique_companies_class_1):
    names_part_1 = class_1.loc[class_1['name_1'] == name, 'name_2'].values
    names_part_2 = class_1.loc[class_1['name_2'] == name, 'name_1'].values
    names = set(names_part_1)
    names.update(names_part_2)
    names.add(name)
    names = sorted(names)
    if len(names) == 1:
        print(names)
    current_cluster = None
    for cur_name in names:
        if cur_name in names_clusters:
            current_cluster = names_clusters[cur_name]
            break
    if current_cluster is None:
        current_cluster = n_clusters
        n_clusters += 1
    for cur_name in names:
        names_clusters[cur_name] = current_cluster
n_clusters -= 1

# %%
print(f'{len(unique_companies_class_1)} компаний из пар с is_duplicate == 1 разбиты на {n_clusters} кластеров')
# Out:
# 1204 компаний из пар с is_duplicate == 1 разбиты на 367 кластеров

# %%
clusters = defaultdict(list)
for k, v in names_clusters.items():
    clusters[v].append(k)

# %% [markdown]
# ## Почистим данные

# %%
symbols_to_drop = ['#', '%', '&', '*', '+', ',', '.', '/', ';',
                   '<', '>', '?', '@', '[', '\\', ']', '`', '{', '\xa0', '«', '±', '»', '¿',
                   'ر', 'س', 'ف', 'ك', 'م', 'و', 'ي', '\u0e00', '‘', '’', '\u3000', '。', '上',
                   '东', '京', '份', '会', '公', '北', '双', '司', '团', '式', '彤', '技', '料',
                   '新', '方', '日', '有', '术', '材', '株', '水', '海', '社', '程', '股', '虹',
                   '防', '限', '集', '雨', '﹠', '＆', '（', '）', '，',  '̇']
symbols_to_replace_with_space = ['-', ':', '"', '(', ')', "'"]
forbidden_words = ['ооо','оао', 'зао', 'лимитед', 'раша', 'групп', 
                   'llc', 'gmbh', 'inc', 'co', 'ltd', 'sa', 'slr', 'limited', 'llp',
                   'ltda', 'asphalt', 'asia', 'europe']

def clean_company_name(name: str,
                       symbols_to_drop: List[str] = symbols_to_drop,
                       symbols_to_replace_with_space: List[str] = symbols_to_replace_with_space,
                       forbidden_words: List[str] = forbidden_words) -> str:
    characters = []
    for c in name:
        if c in symbols_to_drop:
            continue
        elif c in symbols_to_replace_with_space:
            characters.append(' ')
        else:
            characters.append(c)
    replace = {'á': 'a',
               'ã': 'a',
               'ç': 'c',
               'è': 'e',
               'é': 'e',
               'í': 'i',
               'ñ': 'n',
               'ó': 'o',
               'õ': 'o',
               'ö': 'o',
               'ú': 'u',
               'ü': 'u',
               'ę': 'e',
               'ł': 'l',
               'ő': 'o',
               'ş': 's',
               'ű': 'u'}
    
    cleaned_name = ''.join((replace.get(c, c) for c in characters))
    cleaned_name = cleaned_name.strip()
    words = cleaned_name.split()
    cleaned_words = [w for w in words if w not in forbidden_words]
    cleaned_name = ' '.join(cleaned_words)
    return cleaned_name

# %% [markdown]
# ### Очищаем названия компаний из полученных кластеров (clean_clusters)

# %%
clean_clusters = defaultdict(list)
for k, v in clusters.items():
    clean_clusters[k] = [clean_company_name(n.lower()) for n in v]
clean_clusters
# Out:
# defaultdict(list,
#             {0: ['alfagomma', 'alfagomma industrial spa'],
#              1: ['softer spa', 'softer us'],
#              2: ['полимаркет', 'полимаркет', 'полимаркет'],
#              3: ['a westensee partner rohstoff', 'awp rohstoffe'],
#              4: ['api',
#               'trinseo api',
#               'api applicazioni plastiche industriali spa',
#               'api',
#               'api applicazioni plastiche industriali spa'],
#              5: ['abena international as', 'абена'],
#              6: ['adi salambo', 'adi commerce', 'adi commerce'],
#              7: ['adriatica bitumi',
#               'adriatica bitumi spa',
#               'adriatica bitumi spa'],
#              8: ['agip',
#               'agip eni group',
#               'agip spa',
#               'azienda generale italiana petroli'],
#              9: ['alfa laval lund ab', 'альфа лаваль поток'],
#              10: ['alibesa',
#               'andaluza de ligantes bituminosos y betunes en liquidacion',
#               'andaluza de ligante bituminosos y betunes'],
#              11: ['alpha trading', 'alpha trading spa'],
#              12: ['amolplastic leetkooh', 'amol plastic leetkooh'],
#              13: ['ankara insaat',
#               'ankara insaat ticaret ve sanayi sirketi',
#               'ankara insaat'],
#              14: ['aplix', 'aplix'],
#              15: ['appia liants ouest', 'appia liants ouest alo'],
#              16: ['aps', 'aps pavingstone', 'aps paving stone'],
#              17: ['arlanxeo', 'arlanxeo brasil'],
#              18: ['armacell poland sp zoo', 'армаселль'],
#              19: ['as teknik muhendislik yapi ve yalitim malzemeleri aluminyum ve plastik san tic as',
#               'yalteks yalitim malzemeleri san ve tic as',
#               'yalteks yalitim malzemeleri sanayi ve ticaret anonim sirketi'],
#              20: ['asfaltos chova', 'asfaltos chova'],
#              21: ['pharm pack',
#               'общество с ограниченной ответственностью pharm pack'],
#              22: ['automotive performance material apm',
#               'automotive performance material',
#               'automotive performance materials'],
#              23: ['achem technology dongguan',
#               'achem technology dongguan',
#               'achem technology corp'],
#              24: ['adams resources exploration corporation oil and gas assets in crocket and irion counties in texas',
#               'adams resources exploration corporation oil and gas assets outside the permian basin'],
#              25: ['afton chemical de mexicosa de cv',
#               'afton chemical hyderabad pvt',
#               'afton chemical india private',
#               'afton chemical industria de aditivos'],
#              26: ['alan l grant', 'alan l grant polymer'],
#              27: ['arlanxeo',
#               'arlanxeo brasil',
#               'arlanxeo canada',
#               'arlanxeo corp',
#               'arlanxeo international group',
#               'arlanxeo singapore pte',
#               'arlanxeo singapore pte lt',
#               'arlanxeo singapore pte',
#               'arlanxeo singapore pte tearlanxeo canada 1265 vidal',
#               'arlanxeo usa',
#               'ktn underwood arlanxeo usa'],
#              28: ['ashland', 'ashland', 'ashland specialty ingredients gp'],
#              29: ['tar and bitumen', 'plastisavio spa'],
#              30: ['auriquimica', 'auriquimica cnpj', 'auriquimica filial'],
#              31: ['avebe', 'avebe nederland bv'],
#              32: ['avery denisson be', 'avery dennison kunshan'],
#              33: ['bal taban',
#               'bal taban granul ayakkabicilik sanayi ve ticaret sirketi'],
#              34: ['basf cenrtal', 'basf central'],
#              35: ['basf petronas chemicals sdn bhd', 'basf rus'],
#              36: ['bazalt group dortmunder gussasphalt kg dga',
#               'dortmunder gussasphalt kg',
#               'dortmunder gussasphalt kg'],
#              37: ['biesterfeld plastic', 'бистерфельд рус', 'бистерфельд рус'],
#              38: ['binne', 'binne sohn kg', 'binne sohn kg dachbaustoffwerk'],
#              39: ['bit mat products',
#               'bit mat products of michigan',
#               'bit mat products of indiana'],
#              40: ['bitbau', 'bitbau dorr', 'bitbau dorr'],
#              41: ['bitufa', 'bitufa waterproofing bv'],
#              42: ['bitumenka', 'bitumenka dd'],
#              43: ['bitumix', 'bitumix'],
#              44: ['bitumtec former totalerg', 'bitumtec srl', 'bitumtec srl'],
#              45: ['bituver',
#               'saint gobain corporation',
#               'saint gobain isover austria',
#               'isover saint gobain',
#               'saint gobain'],
#              46: ['bochem sudal',
#               'bochem sp z oo zaklady chemiczne',
#               'zaklady chemiczne bochem sp zoo'],
#              47: ['bofer insaat aluminium san ve tic sti', 'боффер'],
#              48: ['bostic', 'bo9stic'],
#              49: ['bostik', 'бостик', 'bostik', 'bostik spzoo'],
#              50: ['bostik nederland bv', 'бостик'],
#              51: ['braas', 'браас дск 1'],
#              52: ['bst elastomers',
#               'jsr corporation tse 4185',
#               'jsr corporation',
#               'jsr bst elastomer',
#               '',
#               'japan synthetic rubber',
#               'jsr america',
#               'jsr tradig',
#               'jsr elastomer america'],
#              53: ['bulmarket dm', 'bulmarket dm'],
#              54: ['basf china shanghai',
#               'basf chile s a',
#               'basf chile',
#               'basf',
#               'basf corp',
#               'basf finlay pvt',
#               'basf india',
#               'basf',
#               'basf auxiliary chemicals',
#               'basf corporation',
#               'basf s paper chemicals huizhou',
#               'basf bangladesh',
#               'basf japan',
#               'basf peruana',
#               'basf colors effects usa',
#               'bdp international basf imp',
#               'basf yeosu',
#               'basf construction chemicals',
#               'basf construction chemicals ua',
#               'basf de costa rica sociedad anonima',
#               'basf india',
#               'basf japan 6 10 1 roppongi',
#               'basf mexicana de cv',
#               'basf new zealand',
#               'basf pakistan private',
#               'basf pakistan',
#               'basf quimica colombiana',
#               'basf turk kimya san ve tictldsti',
#               'basf turk kimya san ve ticsti',
#               'basf turk kimya sanve tic ltdsti'],
#              55: ['beijing oriental yuhong waterproof technology szse 002271',
#               'oriental yuhong'],
#              56: ['bharat adhesives', 'bharat heavy electricals'],
#              57: ['bharat bijlee',
#               'bharat electronics',
#               'bharat enterprises',
#               'bharat polymers',
#               'bharat rubber works pvt'],
#              58: ['biesterfeld international gmb h',
#               'biesterfeld simko distribuicao'],
#              59: ['binex line corp', 'binex line corp vancouver'],
#              60: ['bolton adhesives', 'bolton adhesives bv'],
#              61: ['brenntag australia pty',
#               'brenntag colombia',
#               'brenntag ecuador',
#               'brenntag group',
#               'brenntag peru sac',
#               'brenntag vietnam',
#               'brenntag chile comercial e ind',
#               'brenntag chile comercial e industrial',
#               'brenntag mexico de cv',
#               'brenntag ingredients'],
#              62: ['bridgestone china research and development',
#               'bridgestone huizhou tire',
#               'bridgestone tianjin tire',
#               'bridgestone americas tire',
#               'bridgestone canada',
#               'bridgestone de costa rica',
#               'bridgestone de mexico de cv',
#               'bridgestone firestone de mexico de cv',
#               'bridgestone firestone do brasil',
#               'bridgestone hosepower',
#               'bridgestone india',
#               'bridgestone india pvt',
#               'bridgestone international group',
#               'bridgestone ncr',
#               'bridgestone stargard sp zoo',
#               'bridgestone tire',
#               'bridgestone tire',
#               'bridgestone shenyang tire',
#               'pt bridgestone tire indonesia',
#               'bridgestone firestone de argentina saic',
#               'bridgestone firestone venezolana',
#               'bridgestone firestone venezolana c',
#               'bridgestone golf shenzhen',
#               'bridgestone neumaticos de',
#               'bridgestone neumaticos de monterreysa de cv',
#               'bridgestone huizhousynthetic rubber',
#               'thai bridgestone',
#               'bridgestone de costa rica sociedad anoni',
#               'bridgestone do brasil industria comercio',
#               'bridgestone do brasil industria e comenrcio',
#               'bridgestone do brasil industria e comercio',
#               'bridgestone india automotive products private',
#               'bridgestone india automotive',
#               'shenyang bridgestone',
#               'warren plant bato bridgestone'],
#              63: ['coim spa chimica organica industriale milanese',
#               'coim spa',
#               'coim spa'],
#              64: ['cabopol', 'cabopol polymer compounds'],
#              65: ['calzaturificio franceschetti srl', 'franchescetti'],
#              66: ['cardinal srl', 'cardinal srl'],
#              67: ['casali', 'casali spa'],
#              68: ['cdi energy products divison of fenner advanced sealing technologies',
#               'fenner usa',
#               'fenner dunlop atlanta',
#               'fenner dunlop toledo',
#               'fenner dunlop holdings',
#               'fenner precision'],
#              69: ['celanese bv', 'celanese chemicals'],
#              70: ['cengiz insaat',
#               'cengiz insaat sanayi ve ticaret a s',
#               'cengiz insaat sanayi ve ticaret as'],
#              71: ['clopay',
#               'clopay building products',
#               'clopay building products company'],
#              72: ['cocopaving', 'coco paving'],
#              73: ['colquimica', 'colquimica industria nacional de colas'],
#              74: ['copernit ag', 'copernit spa'],
#              75: ['crafco', 'crafco'],
#              76: ['crosspolimeri spa', 'crosspolimeri spa'],
#              77: ['cts', 'cts corporation nyse cts'],
#              78: ['cardiac science corporation',
#               'cardiac science holdings uk'],
#              79: ['carlisle coatings waterproofing',
#               'carlisle coatings wtrprfng'],
#              80: ['cebu toyo corp',
#               'zhuhai toyo ink',
#               'shanghai toyo ink mfg',
#               'toyo trans'],
#              81: ['celanese materials mexico',
#               'celanese operations mexico s de rl de cv'],
#              82: ['ceva freight',
#               'ceva freight management',
#               'ceva freight management mexico'],
#              83: ['chevron phillips chemical lp', 'phillips tuftex'],
#              84: ['china national petroleum waterproof',
#               'china national petroleum waterproof shenzhen coltd'],
#              85: ['china southern petroleum exploration and development corporation',
#               'jx nippon oil gas exploration myanmar',
#               'jx nippon oil gas exploration brasil',
#               'jx nippon oil gas exploration malaysia',
#               'jx nippon oil gas exploration qatar',
#               'jx nippon oil gas exploration sarawak',
#               'jx nippon oil gas exploration corporation',
#               'jx nippon oil gas exploration technical services corporation',
#               'nippon oil exploration sarawak',
#               'nippon oil exploration',
#               'nippon oil exploration usa',
#               'jx nippon oil gas exploration australia pty'],
#              86: ['compogal', 'компогал'],
#              87: ['continental automotive',
#               'континентал аутомотиве продактс срл'],
#              88: ['contitech antriebssysteme gmb h',
#               'contitech australia pty',
#               'contitech chile',
#               'contitech chile',
#               'contitech india private',
#               'contitech mexicana de cv',
#               'contitech transportbandsysteme gmb h',
#               'contitech usa',
#               'contitech fluid mexicana de cv'],
#              89: ['conveyor rollers bridge', 'kv rollers'],
#              90: ['dalpo',
#               'dalpo poznan sp z o o spolka komandytowa',
#               'dalpo sp z oo'],
#              91: ['danis yapi',
#               'danis yapi madencilik sanayi ve ticaret anonim sirketi'],
#              92: ['danosa', 'danosa france'],
#              93: ['deboer schoten', 'de boer green solutions nv'],
#              94: ['delaval international ab',
#               'делаваль',
#               'delaval international ab'],
#              95: ['delta acm', 'delta roofing'],
#              96: ['demo srl', 'демо'],
#              97: ['ditecpesa', 'ditecpesa'],
#              98: ['doppelmayr cable car kg',
#               'доппельмайр',
#               'doppelmayr seilbahnen'],
#              99: ['dorken kg', 'дёркен'],
#              100: ['dragon poland', 'dragon poland sp z oo spk'],
#              101: ['dukt', 'dukt sp z oo'],
#              102: ['dynasol elastomeros sau', 'dynasol'],
#              103: ['daewoo international america corp',
#               'daewoo international corp',
#               'posco daewoo america corp',
#               'posco daewoo america corp toronto b',
#               'daewoo paper mfgcd',
#               'daewoo spinning mills',
#               'fc daewoo textile',
#               'posco daewoo america corp',
#               'posco daewoo corporation'],
#              104: ['dana', 'dana industrias'],
#              105: ['danisco china', 'danisco india pvt'],
#              106: ['del corona scardigli mexico', 'del corona scardigli usa'],
#              107: ['diesel fashion india reliance private',
#               'reliance brands',
#               'reliance retail',
#               'reliance spg mills',
#               'marks and spencer reliance india pvt',
#               'reliance industries',
#               'reliance bally india private',
#               'reliance clothing india private',
#               'reliance luxury fashion private',
#               'ryohin keikaku reliance india private',
#               'reliance lifestyle holding',
#               'reliance paul shark fashions pvt',
#               'reliance sibur elastomers pvt',
#               'reliance chemical products',
#               'reliance commcl dealers'],
#              108: ['double coin', 'double coin holding'],
#              109: ['dow brasil industria comercio de produtos quimicos lt',
#               'dow brasil sudeste industrial',
#               'dow silicones corp',
#               'dow brasil industria e comercio de produtos quimicos lt',
#               'dow silicones corp plant'],
#              110: ['dow chemical',
#               'dow chemical shanghai',
#               'dow chemical international private',
#               'dow chemical pacific',
#               'dow chemical thailand',
#               'dow international mexicana de',
#               'dow quimica mexicana cv',
#               'dow chemical pacific',
#               'dow international mexicana de cv'],
#              111: ['dow corning 0178 cdw', 'dow corning india pvt'],
#              112: ['dow gmb h', 'dow gmb h plant f208'],
#              113: ['dowdupont', 'the dow chemical company', 'dupont'],
#              114: ['dsv air sea', 'dsv air sea de cv'],
#              115: ['dunlop slazenger international', 'fenner dunlop americas'],
#              116: ['dupont korea',
#               'dupont apollo shenzhen',
#               'dupont do brasil',
#               'dupont mexico',
#               'dupont nutrition usa incc o ceva',
#               'dupont specialty products usa',
#               'dupont teijin films',
#               'eidupont de nemours'],
#              117: ['duracell distributing',
#               'duracell distributing incduracell'],
#              118: ['dynasol elastomeros de cv',
#               'dynasol',
#               'liaoning north dynasol synthetic rubber'],
#              119: ['eiffage',
#               'eiffage construction alpes dauphine',
#               'eiffage enxtpa fgr'],
#              120: ['emam asfaltos', 'емам асфальтос'],
#              121: ['emulbit', 'emulbit sp z oo'],
#              122: ['eneos globe energy', 'eneos globe corporation'],
#              123: ['epiroc drilling solutions', 'эпирок рус'],
#              124: ['esha', 'esha strasse'],
#              125: ['eurovia czechy',
#               'eurovia polska',
#               'eurovia vinci',
#               'eurovia cs',
#               'eurovia polska s a'],
#              126: ['eastland compounders', 'eastland compounding'],
#              127: ['elastron kimya sanayi ve ticaret as',
#               'elastron kimya sanayi ve ticaret anonim sirketi'],
#              128: ['eni jr286',
#               'eni jr286 code 26 273374500',
#               'eni shipping houston'],
#              129: ['eterna s a', 'eterna'],
#              130: ['evonik corp',
#               'evonik corporation stockhausen',
#               'evonik cryo',
#               'evonik cyro',
#               'evonik cyro mobile',
#               'evonik india',
#               'evonik degussa brasil'],
#              131: ['exel logistics', 'exel logistics warehouse'],
#              132: ['exxonmobil pacific r d',
#               'exxonmobil chemical pacific',
#               'exxonmobil chemical',
#               'exxonmobil chemical americas 22777 springwoods village parkway',
#               'exxonmobil chemical americas po box 4549 houston',
#               'exxonmobil quimica',
#               'exxonmobil chemical americas on',
#               'exxonmobil chemical baytown chemical plant',
#               'exxonmobil petroleum and chemical',
#               'exxonmobil servicios petroleros mexico de cv',
#               'exxonmobil japan godo kaisha'],
#              133: ['famos', 'famos kg'],
#              134: ['follmann chemie', 'фольманн'],
#              135: ['forbo eurocol deutschland', 'форбо еврокол рус'],
#              136: ['forbo siegling', 'форбо сиглинг снг'],
#              137: ['ford werke',
#               'общество с ограниченной ответственностью форд соллерс елабуга'],
#              138: ['fourny', 'fourny nv'],
#              139: ['fragmat', 'fragmat tim dd'],
#              140: ['farmacap industria e comercio',
#               'farmacap industries stria e com rcio'],
#              141: ['fatih okce sanayi ve ticaret anonim sirketi',
#               'fatih okce sanayi ve ticaret as'],
#              142: ['flex sol',
#               'hansa flex usa',
#               'k flex usa',
#               'nichirin flex u s a',
#               'planika flex doo',
#               'k flex india private',
#               'l isolante k flex spa',
#               'lisolante k flex spa',
#               'nitro flex x sac',
#               'k flex usa 100 nomaco'],
#              143: ['freudenberg nok componentes brasil',
#               'freudenberg nok de mexico de cv',
#               'freudenberg nok pvt'],
#              144: ['garland', 'the garland company'],
#              145: ['general membrane',
#               'general membrane',
#               'general membrane spa'],
#              146: ['georg boerner',
#               'georg borner chemisches werk fur dach und bautenschutz kg',
#               'georg borner chemisches werk fur dach und bautenschutz kg'],
#              147: ['goldenplast', 'goldenplast spa'],
#              148: ['goter',
#               'goter srl',
#               'goter thermoplastic compounds spa',
#               'goter италия',
#               'goter thermoplastic compounds spa'],
#              149: ['grisard', 'grisard ag'],
#              150: ['gymap group', 'ste gymap'],
#              151: ['gardner gibson', 'гарднер гибсон'],
#              152: ['gates corporation', 'gates usa'],
#              153: ['gates fluid power technologies',
#               'gates fluid power technologies changzhou'],
#              154: ['general electric plastics',
#               'general electric plastics italia srl'],
#              155: ['gestion soprema canada',
#               'soprema blonie',
#               'soprema castellbisbal',
#               'soprema drummondville',
#               'soprema grobbendonk',
#               'soprema oberrossbach',
#               'soprema salgareda',
#               'soprema sourges',
#               'soprema iberia sl',
#               'soprema nv',
#               'soprema polska sp z o o',
#               'soprema',
#               'soprema',
#               'soprema alpiarca',
#               'soprema',
#               'soprema polska sp z oo',
#               'soprema sas',
#               'soprema srl',
#               'soprema iberia',
#               'soprema soprema sas',
#               'soprema canada',
#               'soprema sas'],
#              156: ['giti radial tire anhui',
#               'giti tire hualin',
#               'giti tire usa',
#               'giti tire mfg',
#               'giti tire mfg usa',
#               'giti tire mfg usa',
#               'giti tire mfg'],
#              157: ['gongguan heartychem', 'heartychem corp'],
#              158: ['goodyear',
#               'the goodyear tire and rubber company',
#               'goodyear chemical'],
#              159: ['gymap compound sas', 'gymap sas'],
#              160: ['h v advanced materials india pvt',
#               'h v advanced materials india pvt'],
#              161: ['helios kemostik tovarna lepil in kemicnih izdelkov doo',
#               'хелиос рус'],
#              162: ['hevea bv', 'heveachem international', 'hevea bv'],
#              163: ['hexpol', 'hexpol ab publ om hpol b'],
#              164: ['hilti aktiengesellschaft', 'хилти дистрибьюшн лтд'],
#              165: ['hira middle east', 'hira industries'],
#              166: ['hp pelzer sro', 'хп пельцер рус'],
#              167: ['hubei guochuang hi tech material',
#               'hubei guochuang hi tech material in',
#               'hubei guochuang hi tech material coltd szse 002377'],
#              168: ['huesker synthetic', 'хюскер'],
#              169: ['helm ag', 'helm us corporation'],
#              170: ['hempro ad belex hmbg', 'izobit hempro'],
#              171: ['hexpol compounding',
#               'hexpol compounding uk',
#               'hexpol compounding'],
#              172: ['hikari glass hk', 'hikari glass'],
#              173: ['huizhou lcy elastomers corp', 'lcy elastomers lp'],
#              174: ['icopal', 'icopal kft'],
#              175: ['iko',
#               'iko sas',
#               'iko',
#               'iko sales',
#               'iko eu all plants',
#               'iko slovakia sro',
#               'iko slovakia'],
#              176: ['inreco', 'inreco as'],
#              177: ['inreco emulsja sp z oo', 'inreco emulsje'],
#              178: ['isolago', 'isolago industria de plasticos'],
#              179: ['isoliererzeugnisse grossrohrsdorf',
#               'isoliererzeugnisse grobrohrsdorf'],
#              180: ['isrl', 'indian synthetic rubber'],
#              181: ['izobud', 'izobud group of companies'],
#              182: ['izolacja jarocin spolka akcyjna', 'izolacja jarocin'],
#              183: ['ibaraki zeon kasei coltd',
#               'zeon kasei',
#               'zeon corporation tse 4205',
#               'zs elastomers',
#               'zeon shanghai',
#               'zeon malaysia sdn bhd',
#               'zeon pte',
#               'zeon csc corporation',
#               'zeon chemicals thailand',
#               'zeon',
#               'zeon fb',
#               'zeon india private',
#               'zeon kasei changshu coltd',
#               'zeon medical guangzhou',
#               'zeon medical',
#               'zeon nano technology',
#               'zeon north',
#               'zeon polymix incorporation',
#               'zeon rim',
#               'zeon research vietnam',
#               'zeon do brasil',
#               'zeon logistical materials coltd',
#               'zeon france',
#               'zeon italia srl'],
#              184: ['ikea distribution service shanghai',
#               'ikea distribution services',
#               'ikea distribution services gmb h'],
#              185: ['iko industries', 'iko midwest'],
#              186: ['indian overseas bank',
#               'indian oxides and chemicals private'],
#              187: ['indian synthetic rubber',
#               'indian synthetic rubber private',
#               'indian synthetic rubber pvt'],
#              188: ['industrias negromex', 'negromex'],
#              189: ['ineos styrolution america',
#               'ineos styrolution do brasil polimeros',
#               'ineos styrolution india',
#               'ineos usa'],
#              190: ['intertex world resources', 'интертекс ворлд ресурсис инк'],
#              191: ['izolacja matizol przedsiebiorstwo materialow izolacyjnych',
#               'pmi izolacja matizol',
#               'selena izolacja matizol'],
#              192: ['johns mansville', 'джонс мансвил'],
#              193: ['joss', 'joss elastomers chemicals bv', 'joss holding bv'],
#              194: ['jowat manufacturing sea sdnbhd no25lengkuk teknologi',
#               'йоват'],
#              195: ['jowat se',
#               'йоват',
#               'jowat se через терминал ac pol sad польша',
#               'jowat se через терминал в польше'],
#              196: ['jiangsu baoli international',
#               'jiangsu baoli international investment szse 300135'],
#              197: ['jiangsu canlon building materials',
#               'jiangsu canlon building materials'],
#              198: ['kawasaki heavy industries',
#               'кавасаки газ турбин сервис рус'],
#              199: ['kildair services',
#               'kildair service ulc',
#               'kildair service'],
#              200: ['kimberly clark', 'кимберли кларк'],
#              201: ['kimberly clark nanjing care products', 'кимберли кларк'],
#              202: ['knauf aquapanel kg', 'кнауф аквапанель'],
#              203: ['kraiburg bulgaria eood', 'крайбург'],
#              204: ['kumho petrochemical kose a011780',
#               'kumho',
#               'kumho petrochemical',
#               'kkpc'],
#              205: ['kenda farben india pvt',
#               'kenda rubber china',
#               'kenda rubber tianjin',
#               'kenda rubber industries',
#               'pt kenda rubber indonesia'],
#              206: ['kraton polymers do brasil',
#               'kraton polymers japan',
#               'kraton polymers nederland bv',
#               'kraton polymers trading shanghai',
#               'kraton polymers us',
#               'kraton polymers us',
#               'kraton polymers us',
#               'kraton polymers us'],
#              207: ['kumho petrochemical',
#               'kumho tire goergia',
#               'kumho tire tianjin',
#               'kumho tire changchun',
#               'kumho tire georgia'],
#              208: ['kuraray america',
#               'kuraray india private',
#               'kuraray mexico s de rl de cv'],
#              209: ['lagan bitumen', 'lagan bitumen'],
#              210: ['lectra', 'лектра руссланд', 'lectra'],
#              211: ['lg chem', 'lgchem', 'lg chem'],
#              212: ['lion copolymer holdings', 'lion elastomers'],
#              213: ['lotos asfalt', 'lotos asfalt sp z oo'],
#              214: ['leman usa', 'leman usa atlanta'],
#              215: ['m holland', 'mholland'],
#              216: ['m holland ccp', 'mholland ccp'],
#              217: ['mfp michelin',
#               'michelin group',
#               'michelin siam',
#               'michelin tyre plc',
#               'michelin shenyang tyre',
#               'michelin na asrc',
#               'michelin shenyang tire',
#               'shanghai michelin warrior tyre',
#               'michelin aircraft tire',
#               'michelin americas research',
#               'michelin north america canada',
#               'michelin north america',
#               'michelin research and development center shanghai',
#               'michelin espana portugal',
#               'michelin india private',
#               'shanghai michelin tire',
#               'sociedade michelin de participacoes ind e comercio',
#               'sociedade michelin de participacoes indust e comercio l',
#               'michelin india tamilnadu tyres private',
#               'michelin india technology center',
#               'michelin india technology center'],
#              218: ['makyol',
#               'makyol insaat sanayi turizm ve ticaret as',
#               'makyol insaat sanayi turizm ve ticaret a s'],
#              219: ['malarkey',
#               'malarkey roofing products',
#               'malarkey roofing products'],
#              220: ['maneki japan', 'манеки рус'],
#              221: ['manitou bf', 'маниту восток'],
#              222: ['mapei spa', 'мапеи'],
#              223: ['marangoni retreading systems deutschland',
#               'marangoni retreading systems deutschland'],
#              224: ['marathon', 'marathon oil corporation nyse mro'],
#              225: ['martin', 'martin'],
#              226: ['mct kg',
#               'mct misch compoundier technik',
#               'mct misch compoundiertechnik kg'],
#              227: ['michelin hungaria kft',
#               'michelin polskasimorep et ciesimorep cie',
#               'michelin hungaria tyre manufacture',
#               'мишлен',
#               'michelin',
#               'michelin tires'],
#              228: ['mitas as', 'mitas tires north america'],
#              229: ['mogat',
#               'mogat werke adolf boving bitumen und dachpappenfabrik gesellschaft mit beschrankter haftung',
#               'mogat werke adolf boving bitumen und dachpappen fabrik'],
#              230: ['mondelez',
#               'мон дэлис русь',
#               'мондэлис русь',
#               'mondelez polska production spzoo'],
#              231: ['mondi', 'mondi', 'mondi styria', 'mondi scunthorpe'],
#              232: ['multibase', 'multibase'],
#              233: ['maxwell',
#               'maxwell polymers',
#               'vetus maxwell marine india pvt'],
#              234: ['midland', 'midland materials'],
#              235: ['mitsubishi chemical',
#               'mitsubishi chemical performance',
#               'mitsubishi chemical china commerce',
#               'mitsubishi electric india pvt'],
#              236: ['mitsui canada', 'mitsui usa', 'mitsui'],
#              237: ['mondi osterburken',
#               'nordenia',
#               'nordenia deutschland osterburken'],
#              238: ['netafim', 'нетафим снг'],
#              239: ['nexeo solutions bv', 'нексео солюшенс рус'],
#              240: ['next retail', 'нэкст'],
#              241: ['nknh',
#               'nizhnekamsk',
#               'nizhnekamskneftekhim',
#               'oao nizhnekamskneftekhim'],
#              242: ['obo bettermann produktion deutschland cokg',
#               'обо беттерманн',
#               'обо беттерманн'],
#              243: ['old castle', 'oldcastle building products'],
#              244: ['omv all plants',
#               'omv aktiengesellschaft',
#               'omv aktiengesellschaft wbag omv'],
#              245: ['omur taban', 'omur taban'],
#              246: ['onduline us plants onduline north america',
#               'onduline polska sp z oo',
#               'ондулин',
#               'onduline'],
#              247: ['onur taahhut',
#               'onur taahhut tasimacilik insaat ticaret ve sanayi as'],
#              248: ['orzel',
#               'orzel spolka akcyjna',
#               'orzel spolka akcyjna wse orl'],
#              249: ['owens corning',
#               'owens corning nyse oc',
#               'owens corning glass metal services',
#               'owens corning ht',
#               'owens corning insulating systems',
#               'owens corning sales',
#               'owens corning masonry products business'],
#              250: ['ozsahin suni kosele sanayii ve ticaret anonim sirketi',
#               'ozsahin as'],
#              251: ['ou pigipada', 'pigipada ou'],
#              252: ['pgroup softer deutschland',
#               'softer srl',
#               'softer celanese',
#               'softer'],
#              253: ['parker hannifin', 'parker hannifin usa'],
#              254: ['parker kawakami', 'parker kawakami'],
#              255: ['paul bauder kg',
#               'paul bauder kg stuttgart plant',
#               'paul bauder kg',
#               'paul bauder ag',
#               'paul bauder kg bochum plant',
#               'paul bauder kg landsberg plant',
#               'paul bauder cokg achim plant'],
#              256: ['pavimental', 'pavimental spa'],
#              257: ['perel oy', 'перел'],
#              258: ['peretti bitumi', 'perretti petroli spa'],
#              259: ['petrotekno', 'petrotekno de cv'],
#              260: ['plastay group', 'plastay kimya'],
#              261: ['polyglass', 'polyglass spa'],
#              262: ['polyone', 'polyone corporation nyse pol'],
#              263: ['porr', 'porr ag'],
#              264: ['power adhesives', 'power adhesives'],
#              265: ['probigalp', 'probigalp ligantes betuminosos'],
#              266: ['probisa',
#               'probisa productos bituminosos slu',
#               'probisa productos bituminosos'],
#              267: ['puma energy espana', 'puma energy international bv'],
#              268: ['pafra adhesives', 'pafra adhesives'],
#              269: ['panda logistics usa', 'panda logistics usa new york'],
#              270: ['parker hannifin industria e comercio',
#               'parker hannifin industries e com'],
#              271: ['petro canada international holdings bv',
#               'petro canada oil sands',
#               'petro canada resources usa',
#               'petro canada denmark',
#               'petro canada energy north sea',
#               'petro canada'],
#              272: ['petro canada cooperative holding ua',
#               'petro canada resources usa'],
#              273: ['pikasan plastik kaucuk sanayi as', 'pikasan'],
#              274: ['pirelli de venezuela ca',
#               'pirelli pneus',
#               'pirelli tire',
#               'pirelli tyre',
#               'pirelli neumaticos argentina',
#               'pirelli neumaticos de cv',
#               'pirelli neumaticos de cv',
#               'pirelli neumaticos saic',
#               'pirelli neumaticos',
#               'pirelli neumaticos de',
#               'pirelli neumaticos de cv boulev',
#               'pirelli neumaticos de cv'],
#              275: ['polyglass america mapei', 'полиглас'],
#              276: ['prometeon tyre group industria brasil',
#               'prometeon tyre group srl'],
#              277: ['pt sika indonesia',
#               'sika china',
#               'sika corporation',
#               'sika india private',
#               'sika s a',
#               'sika',
#               'sika cambodia',
#               'sika cambodia warehouse',
#               'sika colombia',
#               'sika singapore pte',
#               'sika kimia sdn bhd',
#               'sika lanka pvt',
#               'sika chile',
#               'sika thailand',
#               'sika vietnam',
#               'sika pakistan pvt',
#               'sika mexicana de cv'],
#              278: ['quandt dachbahnen', 'w quandt kg'],
#              279: ['rasco bitumentechnic', 'rasco bitumentechnik'],
#              280: ['rehau agco', 'рехау продукцион'],
#              281: ['rogitex', 'rogitex international'],
#              282: ['rotoflex ag', 'ао ротофлекс'],
#              283: ['ravago distribution',
#               'ravago group',
#               'ravago hk',
#               'ravago mfg india private',
#               'ravago shah polymers pvt'],
#              284: ['recron malaysia sdn bhd', 'recron malaysia sdnbhd'],
#              285: ['red avenue new materials group',
#               'red avenue new materials group shse 603650'],
#              286: ['rhenocoll werk', 'rhenocoll werk ek'],
#              287: ['rhino rugby',
#               'rhino rugby france',
#               'rhino rugby',
#               'rhino rugby south africa pty'],
#              288: ['rhino sport and leisure', 'rhino sports leisure'],
#              289: ['safic alcan', 'safic alcan polska sp z oo'],
#              290: ['sakhalin energy investment',
#               'филиал компании сахалин энерджи инвестмент компани лтд'],
#              291: ['sanyhot', 'sanyhot adhesivos'],
#              292: ['selena fm', 'селена восток'],
#              293: ['servicom off spec', 'servicom bvmt servi'],
#              294: ['showa rekisei',
#               'showa rekisei industries coltd',
#               'showa shell sekiyu kk',
#               'showa shell'],
#              295: ['sia centrum europa', 'центрум'],
#              296: ['siemens aktiengesellschaft',
#               'сименс технологии газовых турбин'],
#              297: ['sika supply center ag', 'зика'],
#              298: ['simge mat',
#               'simge mat madencilik asfalt ticaret ve sanayi anonim sirketi'],
#              299: ['soudal', 'soudal nv', 'soudal nv'],
#              300: ['soudal nv', 'соудал', 'soudal nv by'],
#              301: ['spc spain', 'spc jevsa slu'],
#              302: ['super beton', 'super beton'],
#              303: ['superbeton', 'superbeton spa'],
#              304: ['swisspor vaparoid',
#               'swisspor polska',
#               'swisspor polska sp z oo'],
#              305: ['sabic innovative plastics mexico s',
#               'sabic innovative plastics us'],
#              306: ['safic alcan group', 'safic alcan italia sp a'],
#              307: ['saint gobain canada',
#               'saint gobain colombia sas',
#               'saint gobain india pvt',
#               'saint gobain performance plastics',
#               'saint gobain vietnam'],
#              308: ['saint gobain performance plastics corporation',
#               'saint gobain performance plastics'],
#              309: ['savino del bene',
#               'savino del bene poland sp z oo',
#               'savino del bene usa'],
#              310: ['shanghai synthomer chemicals',
#               'synthomer uk',
#               'synthomer',
#               'synthomer c oterminal',
#               'synthomer',
#               'synthomer srl',
#               'synthomer c oterminal warehouse',
#               'synthomer peachtree lenox bl bonded logistics 7320 statesville'],
#              311: ['shenzhen comlink electronic',
#               'shenzhen comlink electronics'],
#              312: ['sherwin williams',
#               'the sherwin williams company nyse shw'],
#              313: ['sodex ag', 'содекс аг'],
#              314: ['soprema',
#               'soprema chilliwack',
#               'soprema drummondville',
#               'сопрема'],
#              315: ['sumika polymers mexico s de rl de cv',
#               'sumika polymers north america',
#               'sumika polymers north america'],
#              316: ['sumimoto', 'sumitomo chemical coltd'],
#              317: ['sumitomo bakelite nantong',
#               'sumitomo rubber inds',
#               'sumitomo rubber hunan',
#               'sumitomo rubber do brasil',
#               'sumitomo industrias pesadas do brasil',
#               'sumitomo rubber industries',
#               'sumitomo rubber industries usa',
#               'sumitomo rubber industriesusa',
#               'sumitomo rubber changshu',
#               'sumitomo rubber north america',
#               'sumitomo rubber usa 10 sheridan',
#               'sumitomo rubber usa',
#               'sumitomo warehouse usa'],
#              318: ['sumitomo chemical do brasil representacoes limitada',
#               'sumitomo corporation do brasil'],
#              319: ['sumitomo corp of america',
#               'sumitomo corporation of america'],
#              320: ['sunflag nigeria',
#               'sunflag thailand',
#               'sunflag tanzania',
#               'sunflag nigeria'],
#              321: ['synthos',
#               'synthos dwory 7 spolka',
#               'synthos dwory',
#               'synthos kralupy',
#               'synthos rubber'],
#              322: ['tl squire', 'tl squire'],
#              323: ['takata ag', 'таката рус'],
#              324: ['technonikol', 'technonikol', 'technonikol'],
#              325: ['technpvinyl polymers india',
#               'technovinyl polymers india',
#               'technovinyl polymers india'],
#              326: ['ter group', 'ter hell', 'ter hell or strabeq'],
#              327: ['termocompo',
#               'termocompo industria termoplastica lda',
#               'termocompo industria termoplastica lda'],
#              328: ['termoprene polymers', 'thermoprene'],
#              329: ['tetra pak international', 'ао тетра пак'],
#              330: ['tetra pak technical service ab', 'ао тетра пак'],
#              331: ['three bond', 'three bond'],
#              332: ['toa road', 'toa road corporation tse 1882'],
#              333: ['total bitumen',
#               'total czech republic',
#               'total petrochemicals france',
#               'total polska sp z oo',
#               'total rumunia',
#               'total petrochemicals france',
#               'total romania',
#               'total ceska republika sro',
#               'total france arnay le duc',
#               'total bitumen deutschland',
#               'total bitumen',
#               'total polska'],
#              334: ['tremco illbruck rpm', 'tremco illbruck group'],
#              335: ['tuba taban', 'tuba termo kaucuk taban san ve tic'],
#              336: ['tuermerleim', 'turmerleim', 'turmerleim'],
#              337: ['taiwan synthetic rubber corp', 'tsrc corporation', 'tsrc'],
#              338: ['thuan loi rubber', 'thuan loi rubber'],
#              339: ['tohpe corporation', 'tope seizo kk'],
#              340: ['tokyo zairyo india private',
#               'tokyo zairyo',
#               'tokyo zairyo usa'],
#              341: ['toray carbon fibers america', 'toray carbon fibers'],
#              342: ['toyo tire north',
#               'toyo tire north america',
#               'toyo tires zhangjiagang'],
#              343: ['trinseo gmb h tax id be0806160466',
#               'trinseo gmb h trade register 20162359',
#               'trinseo gmb h trade register 20162359 tax id be0806160466',
#               'trinseo gmb h vat id nl819885150 b01',
#               'trinseo',
#               'trinseo us'],
#              344: ['us ply', 'us ply'],
#              345: ['univar chemicals shanghai univar china',
#               'vm univar edison'],
#              346: ['valley', 'valley corp'],
#              347: ['varo energy', 'varo energy bv'],
#              348: ['vedag', 'vedag bamberg'],
#              349: ['vedag', 'ведаг гмбх'],
#              350: ['versalis', 'versalis spa'],
#              351: ['vetroasfalto', 'vetroasfalto spa'],
#              352: ['versalis americas',
#               'versalis pacific trading shanghai',
#               'versalis pacific trading shanghai',
#               'versalis sp a'],
#              353: ['vestas wind technology china',
#               'vestas wind technology india private'],
#              354: ['wakol', 'wakol'],
#              355: ['warden', 'warden'],
#              356: ['werner janikowo', 'werner janikowo sp z o o'],
#              357: ['wright products',
#               'wright products',
#               'wright products company'],
#              358: ['yokohama',
#               'yokohama corp of north ameri',
#               'yokohama industries americas',
#               'yokohama re mfg',
#               'yokohama rubber the',
#               'yokohama tire corp',
#               'yokohama tire corporation',
#               'yokohama tyre',
#               'yokohama india pvt',
#               'yokohama tire canada',
#               'yokohama tire mfg virgini'],
#              359: ['zanotti spa', 'занотти'],
#              360: ['zeon corporation', 'zeon'],
#              361: ['zeon chemicals lp',
#               'zeon shanghai',
#               'zeon corporation',
#               'zeon trading shanghaico',
#               'zeon advanced polymix',
#               'zeon belts private',
#               'zeon chemicals l p',
#               'zeon produtos quimicos do brasil',
#               'zeon specialty materials'],
#              362: ['ziylan taban santicas',
#               'ziylan taban sanayii ve ticaret anonim sirketi',
#               'ziylan taban'],
#              363: ['konimpex', 'конимпекс'],
#              364: ['pirelli tyre russia', 'пирелли тайр руссия'],
#              365: ['гк полипласт',
#               'полипласт новомосковск',
#               'полипласт северо запад'],
#              366: ['эссиэй хайджин продактс светогорский филиал',
#               'эссиэй хайджин продактс'],
#              367: ['филиал компании эксон нефтегаз',
#               'филиал компании эксон нефтегаз']})

# %% [markdown]
# ### Находим внутри каждого кластера пересечение слов входящих в него компаний, если пересечения нет - то нужно проверить в ручном режиме

# %%
clusters_to_check_manually = []
cluster_words = dict()
for k, v in clean_clusters.items():
    words = set(v[0].split())
    for word in v[1:]:
        words = words.intersection(word.split())
        cluster_words[k] = words
    if len(words) == 0:
        clusters_to_check_manually.append(k)

# %%
for idx in clusters_to_check_manually:
    print(f'{idx} {clean_clusters[idx]}')
# Out:
# 3 ['a westensee partner rohstoff', 'awp rohstoffe']
# 5 ['abena international as', 'абена']
# 8 ['agip', 'agip eni group', 'agip spa', 'azienda generale italiana petroli']
# 9 ['alfa laval lund ab', 'альфа лаваль поток']
# 10 ['alibesa', 'andaluza de ligantes bituminosos y betunes en liquidacion', 'andaluza de ligante bituminosos y betunes']
# 18 ['armacell poland sp zoo', 'армаселль']
# 29 ['tar and bitumen', 'plastisavio spa']
# 37 ['biesterfeld plastic', 'бистерфельд рус', 'бистерфельд рус']
# 45 ['bituver', 'saint gobain corporation', 'saint gobain isover austria', 'isover saint gobain', 'saint gobain']
# 47 ['bofer insaat aluminium san ve tic sti', 'боффер']
# 48 ['bostic', 'bo9stic']
# 49 ['bostik', 'бостик', 'bostik', 'bostik spzoo']
# 50 ['bostik nederland bv', 'бостик']
# 51 ['braas', 'браас дск 1']
# 52 ['bst elastomers', 'jsr corporation tse 4185', 'jsr corporation', 'jsr bst elastomer', '', 'japan synthetic rubber', 'jsr america', 'jsr tradig', 'jsr elastomer america']
# 65 ['calzaturificio franceschetti srl', 'franchescetti']
# 72 ['cocopaving', 'coco paving']
# 86 ['compogal', 'компогал']
# 87 ['continental automotive', 'континентал аутомотиве продактс срл']
# 93 ['deboer schoten', 'de boer green solutions nv']
# 94 ['delaval international ab', 'делаваль', 'delaval international ab']
# 96 ['demo srl', 'демо']
# 98 ['doppelmayr cable car kg', 'доппельмайр', 'doppelmayr seilbahnen']
# 99 ['dorken kg', 'дёркен']
# 113 ['dowdupont', 'the dow chemical company', 'dupont']
# 116 ['dupont korea', 'dupont apollo shenzhen', 'dupont do brasil', 'dupont mexico', 'dupont nutrition usa incc o ceva', 'dupont specialty products usa', 'dupont teijin films', 'eidupont de nemours']
# 120 ['emam asfaltos', 'емам асфальтос']
# 123 ['epiroc drilling solutions', 'эпирок рус']
# 134 ['follmann chemie', 'фольманн']
# 135 ['forbo eurocol deutschland', 'форбо еврокол рус']
# 136 ['forbo siegling', 'форбо сиглинг снг']
# 137 ['ford werke', 'общество с ограниченной ответственностью форд соллерс елабуга']
# 151 ['gardner gibson', 'гарднер гибсон']
# 161 ['helios kemostik tovarna lepil in kemicnih izdelkov doo', 'хелиос рус']
# 162 ['hevea bv', 'heveachem international', 'hevea bv']
# 164 ['hilti aktiengesellschaft', 'хилти дистрибьюшн лтд']
# 166 ['hp pelzer sro', 'хп пельцер рус']
# 168 ['huesker synthetic', 'хюскер']
# 180 ['isrl', 'indian synthetic rubber']
# 183 ['ibaraki zeon kasei coltd', 'zeon kasei', 'zeon corporation tse 4205', 'zs elastomers', 'zeon shanghai', 'zeon malaysia sdn bhd', 'zeon pte', 'zeon csc corporation', 'zeon chemicals thailand', 'zeon', 'zeon fb', 'zeon india private', 'zeon kasei changshu coltd', 'zeon medical guangzhou', 'zeon medical', 'zeon nano technology', 'zeon north', 'zeon polymix incorporation', 'zeon rim', 'zeon research vietnam', 'zeon do brasil', 'zeon logistical materials coltd', 'zeon france', 'zeon italia srl']
# 190 ['intertex world resources', 'интертекс ворлд ресурсис инк']
# 192 ['johns mansville', 'джонс мансвил']
# 194 ['jowat manufacturing sea sdnbhd no25lengkuk teknologi', 'йоват']
# 195 ['jowat se', 'йоват', 'jowat se через терминал ac pol sad польша', 'jowat se через терминал в польше']
# 198 ['kawasaki heavy industries', 'кавасаки газ турбин сервис рус']
# 200 ['kimberly clark', 'кимберли кларк']
# 201 ['kimberly clark nanjing care products', 'кимберли кларк']
# 202 ['knauf aquapanel kg', 'кнауф аквапанель']
# 203 ['kraiburg bulgaria eood', 'крайбург']
# 204 ['kumho petrochemical kose a011780', 'kumho', 'kumho petrochemical', 'kkpc']
# 210 ['lectra', 'лектра руссланд', 'lectra']
# 211 ['lg chem', 'lgchem', 'lg chem']
# 215 ['m holland', 'mholland']
# 220 ['maneki japan', 'манеки рус']
# 221 ['manitou bf', 'маниту восток']
# 222 ['mapei spa', 'мапеи']
# 227 ['michelin hungaria kft', 'michelin polskasimorep et ciesimorep cie', 'michelin hungaria tyre manufacture', 'мишлен', 'michelin', 'michelin tires']
# 230 ['mondelez', 'мон дэлис русь', 'мондэлис русь', 'mondelez polska production spzoo']
# 237 ['mondi osterburken', 'nordenia', 'nordenia deutschland osterburken']
# 238 ['netafim', 'нетафим снг']
# 239 ['nexeo solutions bv', 'нексео солюшенс рус']
# 240 ['next retail', 'нэкст']
# 241 ['nknh', 'nizhnekamsk', 'nizhnekamskneftekhim', 'oao nizhnekamskneftekhim']
# 242 ['obo bettermann produktion deutschland cokg', 'обо беттерманн', 'обо беттерманн']
# 243 ['old castle', 'oldcastle building products']
# 246 ['onduline us plants onduline north america', 'onduline polska sp z oo', 'ондулин', 'onduline']
# 257 ['perel oy', 'перел']
# 258 ['peretti bitumi', 'perretti petroli spa']
# 275 ['polyglass america mapei', 'полиглас']
# 280 ['rehau agco', 'рехау продукцион']
# 282 ['rotoflex ag', 'ао ротофлекс']
# 290 ['sakhalin energy investment', 'филиал компании сахалин энерджи инвестмент компани лтд']
# 292 ['selena fm', 'селена восток']
# 295 ['sia centrum europa', 'центрум']
# 296 ['siemens aktiengesellschaft', 'сименс технологии газовых турбин']
# 297 ['sika supply center ag', 'зика']
# 300 ['soudal nv', 'соудал', 'soudal nv by']
# 313 ['sodex ag', 'содекс аг']
# 314 ['soprema', 'soprema chilliwack', 'soprema drummondville', 'сопрема']
# 316 ['sumimoto', 'sumitomo chemical coltd']
# 323 ['takata ag', 'таката рус']
# 328 ['termoprene polymers', 'thermoprene']
# 329 ['tetra pak international', 'ао тетра пак']
# 330 ['tetra pak technical service ab', 'ао тетра пак']
# 336 ['tuermerleim', 'turmerleim', 'turmerleim']
# 337 ['taiwan synthetic rubber corp', 'tsrc corporation', 'tsrc']
# 339 ['tohpe corporation', 'tope seizo kk']
# 349 ['vedag', 'ведаг гмбх']
# 359 ['zanotti spa', 'занотти']
# 363 ['konimpex', 'конимпекс']
# 364 ['pirelli tyre russia', 'пирелли тайр руссия']

# %% [markdown]
# ### Разберем вручную ключевые слова для этих кластеров

# %%
cluster_words[3] = set(['rohstoff', 'rohstoffe'])
cluster_words[5] = set(['абена', 'abena'])
cluster_words[8] = set(['agip', 'azienda'])
cluster_words[9] = set(['alfa', 'альфа', 'laval', 'лаваль'])
cluster_words[10] = set(['andaluza', 'ligante', 'bituminosos', 'alibesa'])
cluster_words[18] = set(['armacell', 'армаселль'])
cluster_words[29] = set(['bitumen', 'plastisavio'])
cluster_words[37] = set(['бистерфельд', 'biesterfeld'])
cluster_words[45] = set(['bituver', 'saint', 'gobain'])
cluster_words[47] = set(['bofer', 'боффер'])
cluster_words[48] = set(['bostic', 'bo9stic'])
cluster_words[49] = set(['bostik', 'бостик'])
cluster_words[50] = set(['bostik', 'бостик'])
cluster_words[51] = set(['braas', 'браас'])
cluster_words[52] = set(['jsr'])
cluster_words[65] = set(['franceschetti', 'franchescetti'])
cluster_words[72] = set(['coco', 'paving', 'cocopaving'])
cluster_words[86] = set(['компогал', 'compogal'])
cluster_words[87] = set(['continental', 'automotive', 'континентал', 'аутомотиве'])
cluster_words[93] = set(['deboer', 'boer'])
cluster_words[94] = set(['делаваль', 'delaval'])
cluster_words[96] = set(['демо', 'demo'])
cluster_words[98] = set(['doppelmayr', 'доппельмайр'])
cluster_words[99] = set(['dorken', 'дёркен'])
cluster_words[113] = set(['dowdupont', 'dow', 'dupont'])
cluster_words[116] = set(['dupont', 'eidupont'])
cluster_words[120] = set(['емам', 'emam', 'asfaltos', 'асфальтос'])
cluster_words[123] = set(['epiroc', 'эпирок'])
cluster_words[134] = set(['фольманн', 'follmann'])
cluster_words[135] = set(['форбо', 'еврокол', 'forbo', 'eurocol'])
cluster_words[136] = set(['forbo', 'siegling', 'форбо', 'сиглинг'])
cluster_words[137] = set(['ford', 'форд'])
cluster_words[151] = set(['gardner', 'gibson', 'гарднер', 'гибсон'])
cluster_words[161] = set(['helios', 'хелиос'])
cluster_words[162] = set(['hevea', 'heveachem'])
cluster_words[164] = set(['хилти', 'hilti'])
cluster_words[166] = set(['hp', 'pelzer', 'хп', 'пельцер'])
cluster_words[168] = set(['huesker', 'хюскер'])
cluster_words[180] = set(['indian', 'synthetic', 'rubber', 'isrl'])
cluster_words[183] = set(['zeon'])
cluster_words[190] = set(['intertex', 'интертекс'])
cluster_words[192] = set(['johns', 'mansville', 'джонс', 'мансвил'])
cluster_words[194] = set(['jowat', 'йоват'])
cluster_words[195] = set(['jowat', 'йоват'])
cluster_words[198] = set(['kawasaki', 'кавасаки'])
cluster_words[200] = set(['кимберли', 'kimberly', 'clark', 'кларк'])
cluster_words[201] = set(['kimberly', 'кимберли', 'clark', 'кларк'])
cluster_words[202] = set(['кнауф', 'knauf'])
cluster_words[203] = set(['kraiburg', 'крайбург'])
cluster_words[204] = set(['kumho', 'kkpc'])
cluster_words[210] = set(['lectra', 'лектра'])
cluster_words[211] = set(['lgchem', 'lg', 'chem'])
cluster_words[215] = set(['mholland'])
cluster_words[220] = set(['maneki', 'манеки'])
cluster_words[221] = set(['маниту', 'manitou'])
cluster_words[222] = set(['mapei', 'мапеи'])
cluster_words[227] = set(['michelin', 'мишлен'])
cluster_words[230] = set(['мондэлис', 'мон', 'дэлис', 'mondelez'])
cluster_words[237] = set(['nordenia', 'mondi'])
cluster_words[238] = set(['netafim', 'нетафим'])
cluster_words[239] = set(['nexeo', 'нексео'])
cluster_words[240] = set(['нэкст', 'next'])
cluster_words[241] = set(['nizhnekamsk', 'nizhnekamskneftekhim', 'nknh'])
cluster_words[242] = set(['беттерманн', 'обо', 'obo', 'bettermann'])
cluster_words[243] = set(['oldcastle', 'old', 'castle'])
cluster_words[246] = set(['ондулин', 'onduline'])
cluster_words[257] = set(['perel', 'перел'])
cluster_words[258] = set(['peretti', 'perretti'])
cluster_words[275] = set(['pi̇polyglass', 'полиглас'])
cluster_words[280] = set(['рехау', 'rehau'])
cluster_words[282] = set(['rotoflex', 'ротофлекс'])
cluster_words[290] = set(['сахалин', 'энерджи', 'инвестмент', 'sakhalin', 'energy', 'investment'])
cluster_words[292] = set(['selena', 'селена'])
cluster_words[295] = set(['centrum', 'центрум'])
cluster_words[296] = set(['siemens', 'сименс'])
cluster_words[297] = set(['зика', 'sika'])
cluster_words[300] = set(['соудал', 'soudal'])
cluster_words[313] = set(['sodex', 'содекс'])
cluster_words[314] = set(['soprema', 'сопрема'])
cluster_words[316] = set(['sumimoto', 'sumitomo'])
cluster_words[323] = set(['таката', 'takata'])
cluster_words[328] = set(['termoprene', 'thermoprene'])
cluster_words[329] = set(['tetra', 'pak', 'тетра', 'пак'])
cluster_words[330] = set(['tetra', 'pak', 'тетра', 'пак'])
cluster_words[336] = set(['turmerleim', 'tuermerleim'])
cluster_words[337] = set(['tsrc', 'taiwan', 'synthetic', 'rubber'])
cluster_words[339] = set(['tope', 'tohpe'])
cluster_words[349] = set(['vedag', 'ведаг'])
cluster_words[359] = set(['занотти', 'zanotti'])
cluster_words[363] = set(['конимпекс', 'konimpex'])
cluster_words[364] = set(['pirelli', 'пирелли'])

# %% [markdown]
# ## Найдем кластеры для объединения

# %%
cluster_ids = list(cluster_words.keys())

for i in range(len(cluster_words)):
    for j in range(i + 1, len(cluster_words)):
        id_i = cluster_ids[i]
        id_j = cluster_ids[j]
        n_intersection = len(set(cluster_words[id_i]).intersection(cluster_words[id_j]))
        if n_intersection > 0:
            print(f'{id_i} - {cluster_words[id_i]} with {id_j} - {cluster_words[id_j]} by {set(cluster_words[id_i]).intersection(cluster_words[id_j])}')
# Out:
# 1 - {'softer'} with 252 - {'softer'} by {'softer'}
# 13 - {'ankara', 'insaat'} with 70 - {'insaat', 'cengiz'} by {'insaat'}
# 17 - {'arlanxeo'} with 27 - {'arlanxeo'} by {'arlanxeo'}
# 19 - {'ve', 'yalitim', 'malzemeleri'} with 127 - {'ticaret', 'kimya', 'sanayi', 've', 'elastron'} by {'ve'}
# 19 - {'ve', 'yalitim', 'malzemeleri'} with 141 - {'ticaret', 've', 'sanayi', 'okce', 'fatih'} by {'ve'}
# 20 - {'asfaltos', 'chova'} with 120 - {'емам', 'asfaltos', 'emam', 'асфальтос'} by {'asfaltos'}
# 22 - {'automotive', 'performance'} with 87 - {'automotive', 'аутомотиве', 'континентал', 'continental'} by {'automotive'}
# 22 - {'automotive', 'performance'} with 308 - {'performance', 'plastics', 'saint', 'gobain'} by {'performance'}
# 23 - {'achem', 'technology'} with 353 - {'vestas', 'technology', 'wind'} by {'technology'}
# 24 - {'corporation', 'resources', 'gas', 'oil', 'exploration', 'adams', 'assets', 'and'} with 85 - {'exploration'} by {'exploration'}
# 29 - {'bitumen', 'plastisavio'} with 209 - {'bitumen', 'lagan'} by {'bitumen'}
# 33 - {'bal', 'taban'} with 245 - {'omur', 'taban'} by {'taban'}
# 33 - {'bal', 'taban'} with 335 - {'tuba', 'taban'} by {'taban'}
# 33 - {'bal', 'taban'} with 362 - {'taban', 'ziylan'} by {'taban'}
# 34 - {'basf'} with 35 - {'basf'} by {'basf'}
# 34 - {'basf'} with 54 - {'basf'} by {'basf'}
# 35 - {'basf'} with 54 - {'basf'} by {'basf'}
# 37 - {'biesterfeld', 'бистерфельд'} with 58 - {'biesterfeld'} by {'biesterfeld'}
# 39 - {'mat', 'bit', 'products'} with 298 - {'mat', 'simge'} by {'mat'}
# 39 - {'mat', 'bit', 'products'} with 357 - {'products', 'wright'} by {'products'}
# 45 - {'saint', 'bituver', 'gobain'} with 307 - {'saint', 'gobain'} by {'saint', 'gobain'}
# 45 - {'saint', 'bituver', 'gobain'} with 308 - {'performance', 'plastics', 'saint', 'gobain'} by {'saint', 'gobain'}
# 49 - {'бостик', 'bostik'} with 50 - {'бостик', 'bostik'} by {'bostik', 'бостик'}
# 56 - {'bharat'} with 57 - {'bharat'} by {'bharat'}
# 60 - {'adhesives', 'bolton'} with 264 - {'adhesives', 'power'} by {'adhesives'}
# 60 - {'adhesives', 'bolton'} with 268 - {'adhesives', 'pafra'} by {'adhesives'}
# 63 - {'coim', 'spa'} with 76 - {'crosspolimeri', 'spa'} by {'spa'}
# 69 - {'celanese'} with 81 - {'celanese', 'mexico'} by {'celanese'}
# 80 - {'toyo'} with 342 - {'toyo'} by {'toyo'}
# 102 - {'dynasol'} with 118 - {'dynasol'} by {'dynasol'}
# 106 - {'corona', 'scardigli', 'del'} with 309 - {'savino', 'bene', 'del'} by {'del'}
# 109 - {'dow'} with 110 - {'dow'} by {'dow'}
# 109 - {'dow'} with 111 - {'dow', 'corning'} by {'dow'}
# 109 - {'dow'} with 112 - {'dow', 'gmb', 'h'} by {'dow'}
# 109 - {'dow'} with 113 - {'dupont', 'dow', 'dowdupont'} by {'dow'}
# 110 - {'dow'} with 111 - {'dow', 'corning'} by {'dow'}
# 110 - {'dow'} with 112 - {'dow', 'gmb', 'h'} by {'dow'}
# 110 - {'dow'} with 113 - {'dupont', 'dow', 'dowdupont'} by {'dow'}
# 111 - {'dow', 'corning'} with 112 - {'dow', 'gmb', 'h'} by {'dow'}
# 111 - {'dow', 'corning'} with 113 - {'dupont', 'dow', 'dowdupont'} by {'dow'}
# 111 - {'dow', 'corning'} with 249 - {'owens', 'corning'} by {'corning'}
# 112 - {'dow', 'gmb', 'h'} with 113 - {'dupont', 'dow', 'dowdupont'} by {'dow'}
# 112 - {'dow', 'gmb', 'h'} with 160 - {'materials', 'india', 'advanced', 'h', 'pvt', 'v'} by {'h'}
# 113 - {'dupont', 'dow', 'dowdupont'} with 116 - {'dupont', 'eidupont'} by {'dupont'}
# 127 - {'ticaret', 'kimya', 'sanayi', 've', 'elastron'} with 141 - {'ticaret', 've', 'sanayi', 'okce', 'fatih'} by {'sanayi', 'ticaret', 've'}
# 131 - {'logistics', 'exel'} with 269 - {'usa', 'logistics', 'panda'} by {'logistics'}
# 135 - {'форбо', 'eurocol', 'еврокол', 'forbo'} with 136 - {'сиглинг', 'форбо', 'siegling', 'forbo'} by {'форбо', 'forbo'}
# 140 - {'e', 'farmacap'} with 270 - {'e', 'hannifin', 'parker'} by {'e'}
# 145 - {'membrane', 'general'} with 154 - {'general', 'electric', 'plastics'} by {'general'}
# 150 - {'gymap'} with 159 - {'gymap', 'sas'} by {'gymap'}
# 152 - {'gates'} with 153 - {'power', 'gates', 'fluid', 'technologies'} by {'gates'}
# 153 - {'power', 'gates', 'fluid', 'technologies'} with 264 - {'adhesives', 'power'} by {'power'}
# 154 - {'general', 'electric', 'plastics'} with 305 - {'innovative', 'sabic', 'plastics'} by {'plastics'}
# 154 - {'general', 'electric', 'plastics'} with 308 - {'performance', 'plastics', 'saint', 'gobain'} by {'plastics'}
# 155 - {'soprema'} with 314 - {'сопрема', 'soprema'} by {'soprema'}
# 160 - {'materials', 'india', 'advanced', 'h', 'pvt', 'v'} with 197 - {'materials', 'jiangsu', 'canlon', 'building'} by {'materials'}
# 160 - {'materials', 'india', 'advanced', 'h', 'pvt', 'v'} with 285 - {'group', 'materials', 'new', 'red', 'avenue'} by {'materials'}
# 160 - {'materials', 'india', 'advanced', 'h', 'pvt', 'v'} with 325 - {'polymers', 'india'} by {'india'}
# 163 - {'hexpol'} with 171 - {'hexpol', 'compounding'} by {'hexpol'}
# 175 - {'iko'} with 185 - {'iko'} by {'iko'}
# 176 - {'inreco'} with 177 - {'inreco'} by {'inreco'}
# 180 - {'isrl', 'rubber', 'indian', 'synthetic'} with 186 - {'indian'} by {'indian'}
# 180 - {'isrl', 'rubber', 'indian', 'synthetic'} with 187 - {'rubber', 'indian', 'synthetic'} by {'rubber', 'indian', 'synthetic'}
# 180 - {'isrl', 'rubber', 'indian', 'synthetic'} with 337 - {'taiwan', 'rubber', 'tsrc', 'synthetic'} by {'rubber', 'synthetic'}
# 180 - {'isrl', 'rubber', 'indian', 'synthetic'} with 338 - {'loi', 'thuan', 'rubber'} by {'rubber'}
# 182 - {'izolacja', 'jarocin'} with 191 - {'izolacja', 'matizol'} by {'izolacja'}
# 183 - {'zeon'} with 360 - {'zeon'} by {'zeon'}
# 183 - {'zeon'} with 361 - {'zeon'} by {'zeon'}
# 186 - {'indian'} with 187 - {'rubber', 'indian', 'synthetic'} by {'indian'}
# 187 - {'rubber', 'indian', 'synthetic'} with 337 - {'taiwan', 'rubber', 'tsrc', 'synthetic'} by {'rubber', 'synthetic'}
# 187 - {'rubber', 'indian', 'synthetic'} with 338 - {'loi', 'thuan', 'rubber'} by {'rubber'}
# 194 - {'йоват', 'jowat'} with 195 - {'йоват', 'jowat'} by {'йоват', 'jowat'}
# 196 - {'baoli', 'jiangsu', 'international'} with 197 - {'materials', 'jiangsu', 'canlon', 'building'} by {'jiangsu'}
# 197 - {'materials', 'jiangsu', 'canlon', 'building'} with 285 - {'group', 'materials', 'new', 'red', 'avenue'} by {'materials'}
# 200 - {'кимберли', 'кларк', 'kimberly', 'clark'} with 201 - {'кимберли', 'кларк', 'kimberly', 'clark'} by {'кимберли', 'кларк', 'kimberly', 'clark'}
# 204 - {'kkpc', 'kumho'} with 207 - {'kumho'} by {'kumho'}
# 206 - {'polymers', 'kraton'} with 315 - {'polymers', 'sumika'} by {'polymers'}
# 206 - {'polymers', 'kraton'} with 325 - {'polymers', 'india'} by {'polymers'}
# 214 - {'usa', 'leman'} with 269 - {'usa', 'logistics', 'panda'} by {'usa'}
# 217 - {'michelin'} with 227 - {'michelin', 'мишлен'} by {'michelin'}
# 231 - {'mondi'} with 237 - {'nordenia', 'mondi'} by {'mondi'}
# 245 - {'omur', 'taban'} with 335 - {'tuba', 'taban'} by {'taban'}
# 245 - {'omur', 'taban'} with 362 - {'taban', 'ziylan'} by {'taban'}
# 253 - {'hannifin', 'parker'} with 254 - {'kawakami', 'parker'} by {'parker'}
# 253 - {'hannifin', 'parker'} with 270 - {'e', 'hannifin', 'parker'} by {'hannifin', 'parker'}
# 254 - {'kawakami', 'parker'} with 270 - {'e', 'hannifin', 'parker'} by {'parker'}
# 264 - {'adhesives', 'power'} with 268 - {'adhesives', 'pafra'} by {'adhesives'}
# 267 - {'energy', 'puma'} with 290 - {'сахалин', 'investment', 'sakhalin', 'инвестмент', 'energy', 'энерджи'} by {'energy'}
# 267 - {'energy', 'puma'} with 347 - {'energy', 'varo'} by {'energy'}
# 271 - {'petro', 'canada'} with 272 - {'petro', 'canada'} by {'petro', 'canada'}
# 274 - {'pirelli'} with 364 - {'пирелли', 'pirelli'} by {'pirelli'}
# 276 - {'prometeon', 'group', 'tyre'} with 285 - {'group', 'materials', 'new', 'red', 'avenue'} by {'group'}
# 277 - {'sika'} with 297 - {'зика', 'sika'} by {'sika'}
# 287 - {'rhino', 'rugby'} with 288 - {'rhino', 'leisure'} by {'rhino'}
# 289 - {'alcan', 'safic'} with 306 - {'alcan', 'safic'} by {'alcan', 'safic'}
# 290 - {'сахалин', 'investment', 'sakhalin', 'инвестмент', 'energy', 'энерджи'} with 347 - {'energy', 'varo'} by {'energy'}
# 299 - {'soudal'} with 300 - {'соудал', 'soudal'} by {'soudal'}
# 305 - {'innovative', 'sabic', 'plastics'} with 308 - {'performance', 'plastics', 'saint', 'gobain'} by {'plastics'}
# 307 - {'saint', 'gobain'} with 308 - {'performance', 'plastics', 'saint', 'gobain'} by {'saint', 'gobain'}
# 315 - {'polymers', 'sumika'} with 325 - {'polymers', 'india'} by {'polymers'}
# 316 - {'sumitomo', 'sumimoto'} with 317 - {'sumitomo'} by {'sumitomo'}
# 316 - {'sumitomo', 'sumimoto'} with 318 - {'sumitomo', 'do', 'brasil'} by {'sumitomo'}
# 316 - {'sumitomo', 'sumimoto'} with 319 - {'sumitomo', 'america', 'of'} by {'sumitomo'}
# 317 - {'sumitomo'} with 318 - {'sumitomo', 'do', 'brasil'} by {'sumitomo'}
# 317 - {'sumitomo'} with 319 - {'sumitomo', 'america', 'of'} by {'sumitomo'}
# 318 - {'sumitomo', 'do', 'brasil'} with 319 - {'sumitomo', 'america', 'of'} by {'sumitomo'}
# 329 - {'пак', 'pak', 'tetra', 'тетра'} with 330 - {'пак', 'pak', 'tetra', 'тетра'} by {'пак', 'tetra', 'pak', 'тетра'}
# 335 - {'tuba', 'taban'} with 362 - {'taban', 'ziylan'} by {'taban'}
# 337 - {'taiwan', 'rubber', 'tsrc', 'synthetic'} with 338 - {'loi', 'thuan', 'rubber'} by {'rubber'}
# 348 - {'vedag'} with 349 - {'vedag', 'ведаг'} by {'vedag'}
# 350 - {'versalis'} with 352 - {'versalis'} by {'versalis'}
# 360 - {'zeon'} with 361 - {'zeon'} by {'zeon'}

# %% [markdown]
# ## Объединим кластеры

# %%
union_clusters = [
    [1, 252],
    [17, 27],
    [34, 35, 54],
    [37, 58],
    [45, 307, 308],
    [49, 50],
    [56, 57],
    [69, 81],
    [80, 342],
    [102, 118],
    [109, 110, 111, 112, 113],
    [135, 136],
    [150, 159],
    [152, 153],
    [155, 314],
    [163, 171],
    [175, 185],
    [176, 177],
    [180, 187],
    [183, 360, 361],
    [194, 195],
    [200, 201],
    [204, 207],
    [217, 227],
    [231, 237],
    [253, 270],
    [271, 272],
    [274, 364],
    [277, 297],
    [289, 306],
    [299, 300],
    [316, 317, 318, 319],
    [329, 330],
    [348, 349],
    [350, 352]
]

for uc in union_clusters:
    main_id = uc[0]
    for idx in uc[1:]:
        clusters[main_id] = clusters[main_id] + clusters[idx]
        clean_clusters[main_id] = clean_clusters[main_id] + clean_clusters[idx]
        cluster_words[main_id].update(cluster_words[idx])
        del clusters[idx]
        del clean_clusters[idx]
        del cluster_words[idx]

# %% [markdown]
# # Получаем кластеры с ключевыми словами для train

# %%
train_clusters = {}
train_clean_clusters = {}
train_cluster_words = {}

for i, k in enumerate(clean_clusters.keys()):
    train_clusters[i] = clusters[k]
    train_clean_clusters[i] = clean_clusters[k]
    train_cluster_words[i] = cluster_words[k]

# %% [markdown]
# # Сохраним наши результаты

# %%
X_train.to_csv('../data/interim/X_train.csv', index=False)
X_test.to_csv('../data/interim/X_test.csv', index=False)

# %% [markdown]
# ## Сохраним отдельно в X_train_companies.csv названия компаний с номером кластера, и -1 для компаний, для которых не искали кластеры (is_duplicate==0)

# %%
company_cluster = {}
for k, v in train_clusters.items():
    for name in v:
        company_cluster[name] = k

# %%
companies_names = sorted(set(list(X_train['name_1'].unique()) + list(X_train['name_2'].unique())))
companies_with_clusters = [(name, company_cluster.get(name, -1)) for name in companies_names]

company_df = pd.DataFrame(companies_with_clusters, columns=['name', 'cluster'])
company_df
# Out:
#                                                     name  cluster
# 0                                              Alfagomma        0
# 1                                           LANXESS Inc.       -1
# 2                                Lanxess Accounting GmbH       -1
# 3       Lanxess International Trading (Shanghai) Co.,...       -1
# 4                                            Lanxess Sas       -1
# ...                                                  ...      ...
# 17868             ФИЛИАЛ КОМПАНИИ ЭКСОН НЕФТЕГАЗ ЛИМИТЕД      324
# 17869            ФИЛИАЛ КОМПАНИИ"ЭКСОН НЕФТЕГАЗ ЛИМИТЕД"      324
# 17870                               ХИМИНВЕСТ ГРУПП, ООО       -1
# 17871                                 ХИМИНВЕСТ НПФ, ООО       -1
# 17872                                     ЭВЕРИ ДЕННИСОН       -1
#
# [17873 rows x 2 columns]

# %%
# Уберем компанию 'LTD.' - ее название не говорит ни о чем

company_df = company_df[company_df['name'] != 'LTD.'].reset_index(drop=True)

# %%
company_df.to_csv('../data/processed/X_train_companies_with_clusters.csv', index=False)
